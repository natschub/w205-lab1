# %% [markdown]
# # Spacy Demo
#
# If you haven't installed spacy yet, use:
# ```
# conda install spacy
# python -m spacy.en.download
# ```
# This downloads about 500 MB of data.
#
# Another popular package, `nltk`, can be installed as follows (you can skip this for now):
#
# ```
# conda install nltk
# python -m nltk.downloader all
# ```
#
# This also downloads a lot of data

# %% [markdown]
# ## Load StumbleUpon dataset

# %%
# Unicode Handling
from __future__ import unicode_literals

import pandas as pd
import json

data = pd.read_csv("../../assets/dataset/stumbleupon.tsv", sep='\t',
                  encoding="utf-8")
data['title'] = data.boilerplate.map(lambda x: json.loads(x).get('title', ''))
data['body'] = data.boilerplate.map(lambda x: json.loads(x).get('body', ''))
data.head()
# Out:
#                                                  url  urlid  \
# 0  http://www.bloomberg.com/news/2010-12-23/ibm-p...   4042
# 1  http://www.popsci.com/technology/article/2012-...   8471
# 2  http://www.menshealth.com/health/flu-fighting-...   1164
# 3  http://www.dumblittleman.com/2007/12/10-foolpr...   6684
# 4  http://bleacherreport.com/articles/1205138-the...   9006
#
#                                          boilerplate alchemy_category  \
# 0  {"title":"IBM Sees Holographic Calls Air Breat...         business
# 1  {"title":"The Fully Electronic Futuristic Star...       recreation
# 2  {"title":"Fruits that Fight the Flu fruits tha...           health
# 3  {"title":"10 Foolproof Tips for Better Sleep "...           health
# 4  {"title":"The 50 Coolest Jerseys You Didn t Kn...           sports
#
#   alchemy_category_score  avglinksize  commonlinkratio_1  commonlinkratio_2  \
# 0               0.789131     2.055556           0.676471           0.205882
# 1               0.574147     3.677966           0.508021           0.288770
# 2               0.996526     2.382883           0.562016           0.321705
# 3               0.801248     1.543103           0.400000           0.100000
# 4               0.719157     2.676471           0.500000           0.222222
#
#    commonlinkratio_3  commonlinkratio_4  \
# 0           0.047059           0.023529
# 1           0.213904           0.144385
# 2           0.120155           0.042636
# 3           0.016667           0.000000
# 4           0.123457           0.043210
#
#                          ...                          linkwordscore  \
# 0                        ...                                     24
# 1                        ...                                     40
# 2                        ...                                     55
# 3                        ...                                     24
# 4                        ...                                     14
#
#    news_front_page  non_markup_alphanum_characters  numberOfLinks  \
# 0                0                            5424            170
# 1                0                            4973            187
# 2                0                            2240            258
# 3                0                            2737            120
# 4                0                           12032            162
#
#    numwords_in_url  parametrizedLinkRatio  spelling_errors_ratio label  \
# 0                8               0.152941               0.079130     0
# 1                9               0.181818               0.125448     1
# 2               11               0.166667               0.057613     1
# 3                5               0.041667               0.100858     1
# 4               10               0.098765               0.082569     0
#
#                                                title  \
# 0  IBM Sees Holographic Calls Air Breathing Batte...
# 1  The Fully Electronic Futuristic Starting Gun T...
# 2  Fruits that Fight the Flu fruits that fight th...
# 3                10 Foolproof Tips for Better Sleep
# 4  The 50 Coolest Jerseys You Didn t Know Existed...
#
#                                                 body
# 0  A sign stands outside the International Busine...
# 1  And that can be carried on a plane without the...
# 2  Apples The most popular source of antioxidants...
# 3  There was a period in my life when I had a lot...
# 4  Jersey sales is a curious business Whether you...
#
# [5 rows x 29 columns]

# %%
## Load spacy

from spacy.en import English
nlp_toolkit = English()
nlp_toolkit

# %% [markdown]
# Another way to load `spacy`:
# ```
# import spacy
# nlp_toolkit = spacy.load("en")
# ```

# %%
title = u"IBM sees holographic calls, air breathing batteries"
parsed = nlp_toolkit(title)

for (i, word) in enumerate(parsed): 
    print "Word: {}".format(word)
    print "\t Phrase type: {}".format(word.dep_)
    print "\t Is the word a known entity type? {}".format(
        word.ent_type_  if word.ent_type_ else "No")
    print "\t Lemma: {}".format(word.lemma_)
    print "\t Parent of this word: {}".format(word.head.lemma_)

# %% [markdown]
# ## Investigate Page Titles
#
# Let's see if we can find organizations in our page titles.

# %%
def references_organization(title):
    parsed = nlp_toolkit(title)
    return any([word.ent_type_ == 'ORG' for word in parsed])

data['references_organization'] = data['title'].fillna(u'').map(references_organization)

# Take a look
data[data['references_organization']][['title']].head()

# %% [markdown]
# ## Exercise:
#
# Write a function to identify titles that mention an organization (ORG) and a person (PERSON).
#
# .
# .
# .
# .
# .
# .
# .
# .

# %%
## Exercise solution

# %% [markdown]
# ## Predicting "Greenness" Of Content

# %% [markdown]
# This dataset comes from [stumbleupon](https://www.stumbleupon.com/), a web page recommender.
#
# A description of the columns is below

# %% [markdown]
# FieldName|Type|Description
# ---------|----|-----------
# url|string|Url of the webpage to be classified
# title|string|Title of the article
# body|string|Body text of article
# urlid|integer| StumbleUpon's unique identifier for each url
# boilerplate|json|Boilerplate text
# alchemy_category|string|Alchemy category (per the publicly available Alchemy API found at www.alchemyapi.com)
# alchemy_category_score|double|Alchemy category score (per the publicly available Alchemy API found at www.alchemyapi.com)
# avglinksize| double|Average number of words in each link
# commonlinkratio_1|double|# of links sharing at least 1 word with 1 other links / # of links
# commonlinkratio_2|double|# of links sharing at least 1 word with 2 other links / # of links
# commonlinkratio_3|double|# of links sharing at least 1 word with 3 other links / # of links
# commonlinkratio_4|double|# of links sharing at least 1 word with 4 other links / # of links
# compression_ratio|double|Compression achieved on this page via gzip (measure of redundancy)
# embed_ratio|double|Count of number of <embed> usage
# frameBased|integer (0 or 1)|A page is frame-based (1) if it has no body markup but have a frameset markup
# frameTagRatio|double|Ratio of iframe markups over total number of markups
# hasDomainLink|integer (0 or 1)|True (1) if it contains an <a> with an url with domain
# html_ratio|double|Ratio of tags vs text in the page
# image_ratio|double|Ratio of <img> tags vs text in the page
# is_news|integer (0 or 1) | True (1) if StumbleUpon's news classifier determines that this webpage is news
# lengthyLinkDomain| integer (0 or 1)|True (1) if at least 3 <a> 's text contains more than 30 alphanumeric characters
# linkwordscore|double|Percentage of words on the page that are in hyperlink's text
# news_front_page| integer (0 or 1)|True (1) if StumbleUpon's news classifier determines that this webpage is front-page news
# non_markup_alphanum_characters|integer| Page's text's number of alphanumeric characters
# numberOfLinks|integer Number of <a>|markups
# numwords_in_url| double|Number of words in url
# parametrizedLinkRatio|double|A link is parametrized if it's url contains parameters or has an attached onClick event
# spelling_errors_ratio|double|Ratio of words not found in wiki (considered to be a spelling mistake)
# label|integer (0 or 1)|User-determined label. Either evergreen (1) or non-evergreen (0); available for train.tsv only

# %% [markdown]
# > ### Let's try extracting some of the text content.
# > ### Create a feature for the title containing 'recipe'. Is the % of evegreen websites higher or lower on pages that have recipe in the the title?

# %%
# Option 1: Create a function to check for this

def has_recipe(text_in):
    try:
        if 'recipe' in str(text_in).lower():
            return 1
        else:
            return 0
    except: 
        return 0
        
data['recipe'] = data['title'].map(has_recipe)

# Option 2: lambda functions

#data['recipe'] = data['title'].map(lambda t: 1 if 'recipe' in str(t).lower() else 0)


# Option 3: string functions
#data['recipe'] = data['title'].str.contains('recipe')

# %%
data.head()
# Out:
#                                                  url  urlid  \
# 0  http://www.bloomberg.com/news/2010-12-23/ibm-p...   4042
# 1  http://www.popsci.com/technology/article/2012-...   8471
# 2  http://www.menshealth.com/health/flu-fighting-...   1164
# 3  http://www.dumblittleman.com/2007/12/10-foolpr...   6684
# 4  http://bleacherreport.com/articles/1205138-the...   9006
#
#                                          boilerplate alchemy_category  \
# 0  {"title":"IBM Sees Holographic Calls Air Breat...         business
# 1  {"title":"The Fully Electronic Futuristic Star...       recreation
# 2  {"title":"Fruits that Fight the Flu fruits tha...           health
# 3  {"title":"10 Foolproof Tips for Better Sleep "...           health
# 4  {"title":"The 50 Coolest Jerseys You Didn t Kn...           sports
#
#   alchemy_category_score  avglinksize  commonlinkratio_1  commonlinkratio_2  \
# 0               0.789131     2.055556           0.676471           0.205882
# 1               0.574147     3.677966           0.508021           0.288770
# 2               0.996526     2.382883           0.562016           0.321705
# 3               0.801248     1.543103           0.400000           0.100000
# 4               0.719157     2.676471           0.500000           0.222222
#
#    commonlinkratio_3  commonlinkratio_4   ...    news_front_page  \
# 0           0.047059           0.023529   ...                  0
# 1           0.213904           0.144385   ...                  0
# 2           0.120155           0.042636   ...                  0
# 3           0.016667           0.000000   ...                  0
# 4           0.123457           0.043210   ...                  0
#
#    non_markup_alphanum_characters  numberOfLinks  numwords_in_url  \
# 0                            5424            170                8
# 1                            4973            187                9
# 2                            2240            258               11
# 3                            2737            120                5
# 4                           12032            162               10
#
#    parametrizedLinkRatio  spelling_errors_ratio  label  \
# 0               0.152941               0.079130      0
# 1               0.181818               0.125448      1
# 2               0.166667               0.057613      1
# 3               0.041667               0.100858      1
# 4               0.098765               0.082569      0
#
#                                                title  \
# 0  IBM Sees Holographic Calls Air Breathing Batte...
# 1  The Fully Electronic Futuristic Starting Gun T...
# 2  Fruits that Fight the Flu fruits that fight th...
# 3                10 Foolproof Tips for Better Sleep
# 4  The 50 Coolest Jerseys You Didn t Know Existed...
#
#                                                 body  recipe
# 0  A sign stands outside the International Busine...       0
# 1  And that can be carried on a plane without the...       0
# 2  Apples The most popular source of antioxidants...       0
# 3  There was a period in my life when I had a lot...       0
# 4  Jersey sales is a curious business Whether you...       0
#
# [5 rows x 30 columns]

# %% [markdown]
#  ### Demo: Use of the Count Vectorizer

# %%
titles = data['title'].fillna('')

from sklearn.feature_extraction.text import CountVectorizer

#Only consider at max 1000 features (words in our vocab)

vectorizer = CountVectorizer(max_features = 1000, 
                             ngram_range=(1, 2), 
                             stop_words='english',
                             binary=True)

# Use `fit` to learn the vocabulary of the titles
vectorizer.fit(titles)

# Use `tranform` to generate the sample X word matrix - one column per feature (word or n-grams)
X = vectorizer.transform(titles)

# %%
vectorizer.vocabulary_
# Out:
# {u'cooking': 235,
#  u'kids': 499,
#  u'music': 602,
#  u'want': 952,
#  u'wrong': 988,
#  u'angeles slideshows': 56,
#  u'tech': 885,
#  u'rice': 739,
#  u'pretzel': 694,
#  u'fruits': 384,
#  u'cup': 257,
#  u'cooking tips': 237,
#  u'roll': 746,
#  u'street style': 846,
#  u'cooks': 238,
#  u'boost': 119,
#  u'years': 992,
#  u'internet': 481,
#  u'collection 2010': 212,
#  u'photos': 665,
#  u'technology': 889,
#  u'world': 985,
#  u'cream': 245,
#  u'tricks': 918,
#  u'fast food': 350,
#  u'learn': 509,
#  u'symptoms': 873,
#  u'sauce': 761,
#  u'research': 732,
#  u'fruit': 383,
#  u'self': 774,
#  u'recipe epicurious': 718,
#  u'caramel': 160,
#  u'bell': 98,
#  u'cuisine': 255,
#  u'techflesh': 886,
#  u'cheddar': 172,
#  u'parents': 640,
#  u'atlantic': 67,
#  u'video': 943,
#  u'makes': 545,
#  u'robot': 745,
#  u'perfect': 656,
#  u'cheesecakes': 177,
#  u'dishes': 296,
#  u'thanksgiving': 896,
#  u'rings': 741,
#  u'dessert recipes': 284,
#  u'sugarcrafter': 855,
#  u'pies': 673,
#  u'lifestyle': 514,
#  u'brownies': 137,
#  u'cooking food': 236,
#  u'alton brown': 48,
#  u'recipes': 721,
#  u'coffee': 207,
#  u'insidershealth com': 477,
#  u'techniques': 887,
#  u'kitchen': 501,
#  u'cyanide happiness': 267,
#  u'night': 617,
#  u'village voice': 946,
#  u'test': 895,
#  u'concept': 223,
#  u'turns': 923,
#  u'guy': 425,
#  u'pioneer woman': 677,
#  u'decker': 275,
#  u'chip': 189,
#  u'chic': 181,
#  u'brain': 124,
#  u'year': 990,
#  u'apples': 60,
#  u'america': 50,
#  u'casserole recipe': 165,
#  u'snack': 807,
#  u'world news': 986,
#  u'stars': 834,
#  u'inspired': 479,
#  u'free online': 376,
#  u'american': 51,
#  u'culture': 256,
#  u'pictures': 670,
#  u'league': 508,
#  u'smart': 802,
#  u'guide': 424,
#  u'bbc news': 90,
#  u'000': 0,
#  u'popular': 686,
#  u'college fashion': 214,
#  u'8230': 37,
#  u'camera': 156,
#  u'costume': 242,
#  u'slide': 798,
#  u'entertainment': 323,
#  u'times': 904,
#  u'si': 787,
#  u'gallery': 393,
#  u'balsamic': 81,
#  u'breaking news': 131,
#  u'surface': 861,
#  u'party': 644,
#  u'loss': 533,
#  u'lost': 534,
#  u'dresses': 306,
#  u'lose': 532,
#  u'home': 448,
#  u'bar refaeli': 85,
#  u'strawberries': 843,
#  u'star': 833,
#  u'stay': 835,
#  u'enchiladas': 321,
#  u'men': 564,
#  u'technology review': 891,
#  u'movies': 596,
#  u'foods': 370,
#  u'amazing': 49,
#  u'los angeles': 531,
#  u'athletes': 66,
#  u'threat': 901,
#  u'personal': 658,
#  u'school': 768,
#  u'open': 632,
#  u'uses': 933,
#  u'nail': 604,
#  u'ginger': 403,
#  u'parsley': 643,
#  u'tiny': 905,
#  u'basil': 87,
#  u'elle': 319,
#  u'cheesecake recipe': 176,
#  u'yes': 993,
#  u'save': 764,
#  u'oreo': 634,
#  u'magazine': 543,
#  u'com insidershealth': 218,
#  u'muffins': 598,
#  u'disorders': 297,
#  u'brownies recipe': 138,
#  u'eating': 312,
#  u'international': 480,
#  u'filled': 358,
#  u'frosting': 382,
#  u'boy': 123,
#  u'making': 546,
#  u'shoes': 780,
#  u'lunch': 537,
#  u'meme': 562,
#  u'pastry': 646,
#  u'morning': 593,
#  u'buttercream': 149,
#  u'images': 465,
#  u'spicy': 826,
#  u'spice': 824,
#  u'model 2011': 584,
#  u'lasagna': 506,
#  u'soda': 810,
#  u'pesto': 659,
#  u'valentine': 935,
#  u'eggs': 318,
#  u'cupcakes': 259,
#  u'headlines': 434,
#  u'restaurants': 734,
#  u'explosm net': 334,
#  u'restaurant': 733,
#  u'expensive': 332,
#  u'cream cheese': 246,
#  u'cut': 264,
#  u'source': 817,
#  u'san francisco': 758,
#  u'epic': 324,
#  u'insidershealth': 476,
#  u'cure': 261,
#  u'cooker': 227,
#  u'dessert': 282,
#  u'fat': 351,
#  u'wedding': 960,
#  u'really': 713,
#  u'like': 516,
#  u'hair': 427,
#  u'happens': 429,
#  u'female': 354,
#  u'explosm': 333,
#  u'blue': 116,
#  u'mozzarella': 597,
#  u'accessories': 39,
#  u'butter cookies': 148,
#  u'collegehumor': 215,
#  u'salsa': 753,
#  u'diseases': 294,
#  u'days': 273,
#  u'new york': 613,
#  u'recipe blog': 717,
#  u'news': 614,
#  u'cherry': 180,
#  u'dinner': 291,
#  u'picture': 669,
#  u'football': 372,
#  u'pork': 687,
#  u'goes': 410,
#  u'today': 909,
#  u'turn': 922,
#  u'treehugger': 915,
#  u'swimsuit photos': 870,
#  u'turkey': 921,
#  u'illustrated swimsuit': 463,
#  u'week': 961,
#  u'taste': 880,
#  u'tasty': 881,
#  u'list': 518,
#  u'sun': 857,
#  u'salted': 755,
#  u'soccer': 809,
#  u'weight': 963,
#  u'alcohol': 44,
#  u'story': 842,
#  u'cinnamon rolls': 198,
#  u'sweet': 863,
#  u'village': 945,
#  u'cookie recipe': 230,
#  u'healthy': 439,
#  u'polyvore': 683,
#  u'valentine day': 936,
#  u'phone': 660,
#  u'retro': 736,
#  u'sports': 829,
#  u'long': 526,
#  u'rainbow': 705,
#  u'peach': 648,
#  u'nice': 616,
#  u'smitten': 804,
#  u'microsoft': 570,
#  u'taco': 876,
#  u'holiday': 447,
#  u'martha': 552,
#  u'local': 523,
#  u'joy': 492,
#  u'joe': 491,
#  u'remedies': 730,
#  u'g4tv': 391,
#  u'pasta': 645,
#  u'weather': 958,
#  u'cake': 153,
#  u'blogs': 114,
#  u'ice cream': 460,
#  u'womansday': 977,
#  u'chocolate cake': 193,
#  u'miller': 573,
#  u'telegraph': 894,
#  u'foodie': 369,
#  u'machine': 542,
#  u'wine': 972,
#  u'brooklyn decker': 134,
#  u'recipes food': 723,
#  u'best': 100,
#  u'adventures': 41,
#  u'nanny': 605,
#  u'chili': 187,
#  u'unique': 929,
#  u'people': 653,
#  u'g4tv com': 392,
#  u'fox': 373,
#  u'elle com': 320,
#  u'happy': 431,
#  u'team': 884,
#  u'prevent': 695,
#  u'current': 263,
#  u'love': 535,
#  u'visual': 948,
#  u'winter': 974,
#  u'technology news': 890,
#  u'million': 574,
#  u'future': 389,
#  u'allrecipes com': 46,
#  u'better': 102,
#  u'weekly': 962,
#  u'great': 418,
#  u'image': 464,
#  u'having': 433,
#  u'pics': 668,
#  u'science': 769,
#  u'beautiful': 94,
#  u'information': 472,
#  u'mexican': 569,
#  u'year old': 991,
#  u'swimsuit': 865,
#  u'obama': 622,
#  u'play': 679,
#  u'anxiety': 57,
#  u'set': 776,
#  u'sex': 777,
#  u'community': 221,
#  u'funny': 387,
#  u'funny pictures': 388,
#  u'meals': 556,
#  u'results': 735,
#  u'baby': 71,
#  u'garden': 396,
#  u'index': 467,
#  u'casserole': 164,
#  u'high': 445,
#  u'designs': 281,
#  u'cake recipe': 154,
#  u'edition': 314,
#  u'scones': 770,
#  u'hottest': 453,
#  u'2010': 21,
#  u'moments': 589,
#  u'onion': 630,
#  u'betty': 103,
#  u'angeles': 55,
#  u'official': 623,
#  u'francisco': 374,
#  u'fudge': 385,
#  u'2013 check': 27,
#  u'greek': 420,
#  u'green': 421,
#  u'denver': 278,
#  u'smoked': 806,
#  u'truffles': 919,
#  u'hummus': 456,
#  u'com': 217,
#  u'voice': 949,
#  u'drink': 307,
#  u'black bean': 111,
#  u'fight': 357,
#  u'roasted': 744,
#  u'face': 338,
#  u'global': 407,
#  u'si com': 788,
#  u'change': 170,
#  u'best new': 101,
#  u'live': 520,
#  u'sports news': 831,
#  u'cold': 209,
#  u'swimsuit edition': 868,
#  u'space': 820,
#  u'shows': 785,
#  u'breakfast': 129,
#  u'media': 559,
#  u'sylvia anderson': 872,
#  u'touch': 913,
#  u'speed': 823,
#  u'upton': 930,
#  u'real': 710,
#  u'weight loss': 964,
#  u'macaroni cheese': 541,
#  u'joy baker': 493,
#  u'food': 363,
#  u'pretty': 693,
#  u'famous': 345,
#  u'won': 981,
#  u'collegehumor video': 216,
#  u'web': 959,
#  u'trends': 916,
#  u'rolls': 747,
#  u'doesn': 300,
#  u'mores': 592,
#  u'espresso': 327,
#  u'slideshows': 799,
#  u'products': 699,
#  u'halloween': 428,
#  u'attack': 68,
#  u'cute': 265,
#  u'evolution': 329,
#  u'flickr': 362,
#  u'peanut butter': 650,
#  u'8211': 35,
#  u'8217': 36,
#  u'allrecipes': 45,
#  u'candy': 158,
#  u'mushrooms': 601,
#  u'clothes': 201,
#  u'new': 612,
#  u'net': 609,
#  u'dark chocolate': 271,
#  u'mom spark': 588,
#  u'stewart': 837,
#  u'girls': 405,
#  u'medical': 560,
#  u'stop': 839,
#  u'london 2012': 525,
#  u'facts': 340,
#  u'apple pie': 59,
#  u'swimsuit collection': 867,
#  u'burn': 144,
#  u'healthy recipes': 441,
#  u'classic': 200,
#  u'diet': 289,
#  u'skin': 795,
#  u'yummy': 998,
#  u'olympic': 628,
#  u'refaeli si': 729,
#  u'olive': 627,
#  u'crazy': 244,
#  u'pink': 675,
#  u'designer': 280,
#  u'collection 2008': 211,
#  u'york best': 995,
#  u'coconut': 206,
#  u'marijuana': 550,
#  u'pain': 637,
#  u'black': 110,
#  u'cancer': 157,
#  u'savory': 765,
#  u'strawberry': 844,
#  u'videos': 944,
#  u'field': 356,
#  u'students': 848,
#  u'buffalo': 139,
#  u'reality': 712,
#  u'fall': 342,
#  u'search': 772,
#  u'edition check': 315,
#  u'blood': 115,
#  u'dough': 304,
#  u'habits': 426,
#  u'pan': 638,
#  u'create': 249,
#  u'secret': 773,
#  u'fun': 386,
#  u'mom': 587,
#  u'pea': 647,
#  u'health benefits': 436,
#  u'homemade': 449,
#  u'hot chocolate': 452,
#  u'edition si': 316,
#  u'peanut': 649,
#  u'crocker': 252,
#  u'feta': 355,
#  u'la': 505,
#  u'll': 522,
#  u'photos sports': 666,
#  u'cures': 262,
#  u'monkey': 591,
#  u'youtube': 997,
#  u'fashion week': 348,
#  u'national': 606,
#  u'recipe allrecipes': 716,
#  u'works': 984,
#  u'buy': 151,
#  u'minutes': 578,
#  u'baker': 76,
#  u'baked': 75,
#  u'hate': 432,
#  u'street': 845,
#  u'mess': 568,
#  u'using': 934,
#  u'grilled cheese': 423,
#  u'women fashion': 980,
#  u'got': 415,
#  u'fashion': 347,
#  u'random': 706,
#  u'geek': 398,
#  u'twice': 926,
#  u'shots': 784,
#  u'beer': 97,
#  u'greatest': 419,
#  u'gifs': 402,
#  u'ice': 459,
#  u'christmas': 196,
#  u'corn': 241,
#  u'com photos': 219,
#  u'foods eat': 371,
#  u'bake': 74,
#  u'cinnamon': 197,
#  u'weird': 965,
#  u'chocolate': 192,
#  u'healthy food': 440,
#  u'pro': 697,
#  u'dining': 290,
#  u'model': 583,
#  u'food photography': 367,
#  u'10 things': 3,
#  u'oh': 624,
#  u'mental': 566,
#  u'parmesan': 642,
#  u'woman': 975,
#  u'worst': 987,
#  u'tea': 882,
#  u'ted': 892,
#  u'design': 279,
#  u'dessert recipe': 283,
#  u'breaking': 130,
#  u'tomatoes': 911,
#  u'health': 435,
#  u'sweet potato': 864,
#  u'reasons': 714,
#  u'recipe simply': 720,
#  u'10 best': 2,
#  u'build': 141,
#  u'fast': 349,
#  u'fried': 380,
#  u'food recipes': 368,
#  u'lemon': 510,
#  u'coffee cake': 208,
#  u'south': 818,
#  u'sexy': 778,
#  u'stewart recipes': 838,
#  u'heart': 442,
#  u'use': 932,
#  u'carrot': 163,
#  u'looks': 529,
#  u'2008 sports': 19,
#  u'raw': 708,
#  u'orange': 633,
#  u'nfl': 615,
#  u'meatballs': 558,
#  u'apps': 61,
#  u'record': 725,
#  u'betty crocker': 104,
#  u'thyme': 902,
#  u'soup': 814,
#  u'dipping': 293,
#  u'simple recipes': 792,
#  u'support': 860,
#  u'inside': 475,
#  u'models': 585,
#  u'sign': 790,
#  u'fake': 341,
#  u'pumpkin': 702,
#  u'awesome': 70,
#  u'natural': 607,
#  u'beauty': 95,
#  u'soup recipe': 815,
#  u'city': 199,
#  u'stuffed': 850,
#  u'refaeli': 728,
#  u'recipe food': 719,
#  u'dark': 270,
#  u'woman cooks': 976,
#  u'blog archive': 113,
#  u'mnn': 581,
#  u'tv': 925,
#  u'cyanide': 266,
#  u'death': 274,
#  u'person': 657,
#  u'spring': 832,
#  u'buffalo chicken': 140,
#  u'uk': 927,
#  u'fresh': 379,
#  u'2013 sports': 28,
#  u'try': 920,
#  u'spaghetti': 821,
#  u'york village': 996,
#  u'challenge': 169,
#  u'tomato': 910,
#  u'artichoke': 64,
#  u'2011': 23,
#  u'2013': 26,
#  u'2012': 25,
#  u'white chocolate': 969,
#  u'sylvia': 871,
#  u'runway': 750,
#  u've': 938,
#  u'site': 794,
#  u'vs': 950,
#  u'android': 54,
#  u'irish': 484,
#  u'life': 512,
#  u'red': 726,
#  u'chef': 179,
#  u'crunch': 253,
#  u'mac cheese': 539,
#  u'items': 487,
#  u'player': 680,
#  u'beach': 92,
#  u'pizza': 678,
#  u'avocado': 69,
#  u'salted caramel': 756,
#  u'medicine': 561,
#  u'delicious': 277,
#  u'exercises': 331,
#  u'air': 43,
#  u'photo': 662,
#  u'post': 688,
#  u'old': 626,
#  u'way': 955,
#  u'welcome': 966,
#  u'banana bread': 83,
#  u'history': 446,
#  u'car': 159,
#  u'clothing': 202,
#  u'mike': 571,
#  u'menus': 567,
#  u'care': 162,
#  u'nutrition': 620,
#  u'german': 399,
#  u'trick': 917,
#  u'cupcake': 258,
#  u'rules': 749,
#  u'wheat': 967,
#  u'los': 530,
#  u'low': 536,
#  u'time': 903,
#  u'peas': 651,
#  u'cookies': 231,
#  u'vegetarian': 941,
#  u'family': 343,
#  u'takes': 878,
#  u'help': 444,
#  u'soon': 813,
#  u'indie urban': 470,
#  u'maple': 549,
#  u'banana': 82,
#  u'center': 168,
#  u'latest': 507,
#  u'chocolate chip': 194,
#  u'slow cooker': 801,
#  u'look': 528,
#  u'chicken recipes': 185,
#  u'ready': 709,
#  u'game': 394,
#  u'wings': 973,
#  u'kitchens food': 503,
#  u'men health': 565,
#  u'desserts': 285,
#  u'infographic': 471,
#  u'kate': 495,
#  u'boots': 120,
#  u'sausage': 763,
#  u'bakers': 77,
#  u'management': 548,
#  u'food cooking': 365,
#  u'bbc food': 89,
#  u'page': 636,
#  u'cranberry': 243,
#  u'kitchens': 502,
#  u'eat': 311,
#  u'stories': 841,
#  u'baking': 78,
#  u'sleep': 797,
#  u'101': 6,
#  u'10 ways': 4,
#  u'meat': 557,
#  u'roast': 743,
#  u'rosemary': 748,
#  u'meal': 555,
#  u'velvet': 942,
#  u'mini': 576,
#  u'modern': 586,
#  u'mind': 575,
#  u'mint': 577,
#  u'mashed': 554,
#  u'don': 303,
#  u'dog': 301,
#  u'sugar': 853,
#  u'grilled': 422,
#  u'make': 544,
#  u'butter': 147,
#  u'human': 455,
#  u'kate upton': 496,
#  u'potato': 690,
#  u'tacos': 877,
#  u'reviews': 738,
#  u'mac': 538,
#  u'man': 547,
#  u'chip cookies': 190,
#  u'food network': 366,
#  u'thing': 897,
#  u'think': 899,
#  u'cheese': 173,
#  u'eyed': 336,
#  u'11': 8,
#  u'10': 1,
#  u'13': 10,
#  u'12': 9,
#  u'15': 12,
#  u'14': 11,
#  u'18': 15,
#  u'cheesecake': 175,
#  u'shop': 781,
#  u'shot': 783,
#  u'pie recipe': 672,
#  u'cookie dough': 229,
#  u'oil': 625,
#  u'money': 590,
#  u'served': 775,
#  u'pioneer': 676,
#  u'gomes': 412,
#  u'film': 359,
#  u'table': 875,
#  u'eye': 335,
#  u'advice': 42,
#  u'playing': 681,
#  u'24': 30,
#  u'25': 31,
#  u'20': 16,
#  u'22': 29,
#  u'energy': 322,
#  u'granola': 417,
#  u'print': 696,
#  u'zucchini': 999,
#  u'salmon': 752,
#  u'common': 220,
#  u'fans': 346,
#  u'cakes': 155,
#  u'simple': 791,
#  u'simply': 793,
#  u'oatmeal': 621,
#  u'cream sauce': 247,
#  u'treats': 914,
#  u'exercise': 330,
#  u'3d': 33,
#  u'30': 32,
#  u'snacks': 808,
#  u'recipes cooking': 722,
#  u'jessica': 489,
#  u'mix': 580,
#  u'mit': 579,
#  u'skinny': 796,
#  u'technologies': 888,
#  u'health com': 437,
#  u'improve': 466,
#  u'italian': 486,
#  u'pepper': 654,
#  u'vegetables': 940,
#  u'biggest': 106,
#  u'swimsuit 2013': 866,
#  u'almond': 47,
#  u'fabulous': 337,
#  u'ultimate': 928,
#  u'london': 524,
#  u'potatoes': 691,
#  u'fitness': 361,
#  u'urban': 931,
#  u'watch': 953,
#  u'report': 731,
#  u'wear': 957,
#  u'store': 840,
#  u'games': 395,
#  u'drugs': 308,
#  u'mother': 594,
#  u'tutorial': 924,
#  u'cook': 225,
#  u'cool': 239,
#  u'healthier': 438,
#  u'iphone': 483,
#  u'clutch': 203,
#  u'ideas': 461,
#  u'hungry': 458,
#  u'solar': 812,
#  u'college': 213,
#  u'key': 497,
#  u'pot': 689,
#  u'pop': 684,
#  u'shrimp': 786,
#  u'heather': 443,
#  u'chinese': 188,
#  u'dish': 295,
#  u'crust': 254,
#  u'decker si': 276,
#  u'style': 852,
#  u'cookie': 228,
#  u'cookin': 234,
#  u'feel': 353,
#  u'gourmet': 416,
#  u'check': 171,
#  u'water': 954,
#  u'crispy': 251,
#  u'marshmallow': 551,
#  u'womansday com': 978,
#  u'memory': 563,
#  u'mustard': 603,
#  u'network kitchens': 611,
#  u'martha stewart': 553,
#  u'light': 515,
#  u'chips': 191,
#  u'wall': 951,
#  u'2010 sports': 22,
#  u'gets': 400,
#  u'ingredients': 474,
#  u'red velvet': 727,
#  u'asian': 65,
#  u'bacon': 72,
#  u'gluten free': 409,
#  u'hot': 451,
#  u'boston': 121,
#  u'glass': 406,
#  u'wtf': 989,
#  u'100': 5,
#  u'things': 898,
#  u'burgers': 143,
#  u'easy': 310,
#  u'right': 740,
#  u'creative': 250,
#  u'recipe': 715,
#  u'50': 34,
#  u'stress': 847,
#  u'teacher': 883,
#  u'san': 757,
#  u'say': 766,
#  u'swimsuit photo': 869,
#  u'salt': 754,
#  u'sugar cookies': 854,
#  u'slow': 800,
#  u'spark': 822,
#  u'summer': 856,
#  u'smitten kitchen': 805,
#  u'power': 692,
#  u'favorite': 352,
#  u'project': 700,
#  u'smile': 803,
#  u'cnn com': 205,
#  u'kick': 498,
#  u'teen': 893,
#  u'cookbooks': 226,
#  u'dress': 305,
#  u'jessica gomes': 490,
#  u'sport': 828,
#  u'brooklyn': 133,
#  u'movie': 595,
#  u'tools': 912,
#  u'101 cookbooks': 7,
#  u'food blog': 364,
#  u'tart': 879,
#  u'illustrated': 462,
#  u'balls': 80,
#  u'going': 411,
#  u'doing': 302,
#  u'pudding': 701,
#  u'npr': 618,
#  u'device': 286,
#  u'2011 sports': 24,
#  u'broccoli': 132,
#  u'caramelized': 161,
#  u'does': 299,
#  u'inspiration': 478,
#  u'phones': 661,
#  u'blueberry': 117,
#  u'indie': 468,
#  u'break': 127,
#  u'bread': 125,
#  u'network': 610,
#  u'garlic': 397,
#  u'iron': 485,
#  u'si swimsuit': 789,
#  u'toast': 908,
#  u'steak': 836,
#  u'quotes': 704,
#  u'humor': 457,
#  u'archive': 62,
#  u'scores': 771,
#  u'brown': 135,
#  u'brownie': 136,
#  u'vegan': 939,
#  u'southern': 819,
#  u'raspberry': 707,
#  u'online': 631,
#  u'coolest': 240,
#  u'epicurious': 325,
#  u'business': 145,
#  u'beef': 96,
#  u'egg': 317,
#  u'actually': 40,
#  u'super bowl': 859,
#  u'ball': 79,
#  u'mobile': 582,
#  u'probably': 698,
#  u'sandwiches': 760,
#  u'facebook': 339,
#  u'cell': 167,
#  u'salad': 751,
#  u'control': 224,
#  u'cookies recipe': 233,
#  u'need': 608,
#  u'computer': 222,
#  u'police': 682,
#  u'museum': 599,
#  u'gluten': 408,
#  u'tips': 907,
#  u'pancakes': 639,
#  u'ivillage': 488,
#  u'pecan': 652,
#  u'honey': 450,
#  u'workout': 983,
#  u'little': 519,
#  u'spinach': 827,
#  u'threadsence': 900,
#  u'butt': 146,
#  u'bar': 84,
#  u'17': 14,
#  u'16': 13,
#  u'bad': 73,
#  u'olympics': 629,
#  u'mushroom': 600,
#  u'study': 849,
#  u'sushi': 862,
#  u'just': 494,
#  u'super': 858,
#  u'daily': 268,
#  u'milk': 572,
#  u'finally': 360,
#  u'did': 287,
#  u'die': 288,
#  u'diy': 298,
#  u'dip': 292,
#  u'work': 982,
#  u'french': 377,
#  u'creamy': 248,
#  u'sharing': 779,
#  u'sour': 816,
#  u'bites': 109,
#  u'girl': 404,
#  u'living': 521,
#  u'stupid': 851,
#  u'fries': 381,
#  u'shopping': 782,
#  u'everyday': 328,
#  u'chicken recipe': 184,
#  u'children': 186,
#  u'celebrity': 166,
#  u'burger': 142,
#  u'abs': 38,
#  u'eats': 313,
#  u'good': 413,
#  u'biscuits': 108,
#  u'house': 454,
#  u'benefits': 99,
#  u'cups': 260,
#  u'life style': 513,
#  u'big': 105,
#  u'google': 414,
#  u'cheese frosting': 174,
#  u'cheesy': 178,
#  u'2007': 17,
#  u'2008': 18,
#  u'2009': 20,
#  u'ingredient': 473,
#  u'recipes ivillage': 724,
#  u'chicago': 182,
#  u'body': 118,
#  u'lime': 517,
#  u'collection': 210,
#  u'day': 272,
#  u'indie clothing': 469,
#  u'ipad': 482,
#  u'photography': 664,
#  u'bean': 93,
#  u'break com': 128,
#  u'soft': 811,
#  u'dangerous': 269,
#  u'pic': 667,
#  u'pig': 674,
#  u'paris': 641,
#  u'risk': 742,
#  u'pie': 671,
#  u'oven': 635,
#  u'real simple': 711,
#  u'free': 375,
#  u'pops': 685,
#  u'earth': 309,
#  u'cajun': 152,
#  u'cnn': 204,
#  u'anderson': 53,
#  u'tip': 906,
#  u'longer': 527,
#  u'family kitchen': 344,
#  u'quick': 703,
#  u'french toast': 378,
#  u'birthday': 107,
#  u'white': 968,
#  u'future technology': 390,
#  u'chocolate peanut': 195,
#  u'ways': 956,
#  u'review': 737,
#  u'bowl': 122,
#  u'macaroni': 540,
#  u'kill': 500,
#  u'blog': 112,
#  u'sandwich': 759,
#  u'syrup': 874,
#  u'photo gallery': 663,
#  u'epicurious com': 326,
#  u'windows': 971,
#  u'bars': 86,
#  u'art': 63,
#  u'nutella': 619,
#  u'wild': 970,
#  u'sports illustrated': 830,
#  u'analysis': 52,
#  u'peppermint': 655,
#  u'spiced': 825,
#  u'apple': 58,
#  u'women': 979,
#  u'york': 994,
#  u'chicken': 183,
#  u'bbc': 88,
#  u'bbq': 91,
#  u'vanilla': 937,
#  u'lemonade': 511,
#  u'vintage': 947,
#  u'buttermilk': 150,
#  u'happiness': 430,
#  u'cookies cream': 232,
#  u'know': 504,
#  u'says': 767,
#  u'getting': 401,
#  u'bread recipe': 126,
#  u'sauce recipe': 762}

# %%
vectorizer.vocabulary_.contains('fruits')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c4fea843d628> in <module>()
# ----> 1 vectorizer.vocabulary_.contains('fruits')
#
# AttributeError: 'dict' object has no attribute 'contains'

# %%
data['title']
# Out:
# 0    IBM Sees Holographic Calls Air Breathing Batte...
# 1    The Fully Electronic Futuristic Starting Gun T...
# 2    Fruits that Fight the Flu fruits that fight th...
# 3                  10 Foolproof Tips for Better Sleep
# 4    The 50 Coolest Jerseys You Didn t Know Existed...
# Name: title, dtype: object

# %%
X.toarray().shape
# Out:
# (7395, 1000)

# %% [markdown]
# X is a sparse matrix. This means that most of the entries in the matrix are zeros. Why? Most documents only contain a small subset of the total vocabulary.
#
# The data type of X is a Compressed Sparse Row Format. You can convert it to a numpy array by using .toarray() i.e. X.toarray()

# %% [markdown]
#  ### Demo: Build a random forest model to predict evergreeness of a website using the title features

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 20)
    
# Use `fit` to learn the vocabulary of the titles
vectorizer.fit(titles)

# Use `tranform` to generate the sample X word matrix - one column per feature (word or n-grams)
X = vectorizer.transform(titles).toarray()
y = data['label']

from sklearn.cross_validation import cross_val_score

scores = cross_val_score(model, X, y, scoring='roc_auc')
print('CV AUC {}, Average AUC {}'.format(scores, scores.mean()))

# %% [markdown]
# ### Exercise: Build a random forest model to predict evergreeness of a website using the title features and quantitative features

# %%
## TODO

# %% [markdown]
#  ### Exercise: Build a random forest model to predict evergreeness of a website using the body features

# %%
## TODO

# %% [markdown]
#  ### Exercise: Use `TfIdfVectorizer` instead of `CountVectorizer` - is this an improvement?

# %%
## TODO
